# %% [markdown]
# # ML Concepts Notes
#
# ## Beginner-friendly summary
# This notebook is a lightweight concept guide. It organizes key machine-learning ideas so each later project notebook is easier to follow.
#
# ### What this notebook does
# - Defines core supervised learning terms
# - Explains common evaluation metrics
# - Clarifies probability vs classification decisions
# - Introduces overfitting/underfitting intuition
# - Connects concepts to practical model workflow
#
# ### Major steps (in order)
# 1. Core terminology
# 2. Problem framing
# 3. Metrics and error types
# 4. Probability, threshold, and calibration basics
# 5. Overfitting and validation basics
# 6. Practical checklist for model work
#
# ### Side notes for beginners
# - Accuracy alone is often not enough; use problem-appropriate metrics.
# - Probability scores and class labels are related but not the same thing.
# - Validation performance matters more than training performance for generalization.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import numpy as np

# Generate synthetic data
X, y = make_regression(n_samples=1000, n_features=10, noise=0.1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Train model twice WITHOUT fixing random_state
model1 = RandomForestRegressor()
model1.fit(X_train, y_train)
pred1 = model1.predict(X_test[:5])

model2 = RandomForestRegressor()
model2.fit(X_train, y_train)
pred2 = model2.predict(X_test[:5])

print("Predictions run 1:", pred1)
print("Predictions run 2:", pred2)

print("\nDifference:", pred1 - pred2)
# Out:
# Predictions run 1: [ 134.25794655 -118.78320459   28.22644356  210.14627048   -1.59923867]
# Predictions run 2: [ 121.64066544 -145.07863986   17.08048578  200.89486969   12.29565137]
#
# Difference: [ 12.61728112  26.29543527  11.14595778   9.25140079 -13.89489005]
